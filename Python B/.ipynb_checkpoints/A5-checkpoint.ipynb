# %%
file0=open("file.txt","r")

content=file0.read()
print(content)

file0.close()
# Out:
# hello i'am new word

# %%
file1= open("file.txt","w+")
file1.write("hello i'am new word2 ")

file1.seek(0)

content = file1.read()
print(content)
file1.close()
# Out:
# hello i'am new word2
